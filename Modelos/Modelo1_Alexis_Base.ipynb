# %% [markdown]
# # Modelo base: Random Forest

# %% [markdown]
# La idea es generar un modelo base que nos servirá como referencia. Será algo simple: un Random Forest
#
# Tomaremos un dataset balanceado entre bonafide y spoof, y los diferentes attack_id
